# %% [markdown]
# # Retail Demand Forecasting: EDA and Modeling
# This notebook provides a readable exploratory path. The production pipeline lives in `src/`.

# %%
import pandas as pd
from pathlib import Path
ROOT = Path('..')
df = pd.read_csv(ROOT/'data/raw/retail_sales.csv', parse_dates=['date'])
df.head()

# %%
df.shape, df['store_id'].nunique(), df['sku_id'].nunique(), df['date'].min(), df['date'].max()

# %%
df.groupby('category')['units_sold'].agg(['mean','sum']).sort_values('sum', ascending=False)

# %% [markdown]
# ## Modeling
# Run `python ../src/pipeline.py` from the repository root for the reproducible training, evaluation, SHAP, and inventory workflow.

# %%
import json
metrics = json.loads((ROOT/'outputs/metrics.json').read_text())
metrics
